# %%
# !pip install -r ../requirements.txt
# Out:
# Ignoring colorama: markers 'sys_platform == "win32"' don't match your environment
# Ignoring cuda-bindings: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring cuda-pathfinder: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cublas-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cuda-cupti-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cuda-nvrtc-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cuda-runtime-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cudnn-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cufft-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cufile-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-curand-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cusolver-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cusparse-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-cusparselt-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-nccl-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-nvjitlink-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-nvshmem-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring nvidia-nvtx-cu12: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring triton: markers 'platform_machine == "x86_64" and sys_platform == "linux"' don't match your environment
# Ignoring tzdata: markers 'sys_platform == "emscripten" or sys_platform == "win32"' don't match your environment
# Requirement already satisfied: absl-py==2.4.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiohttp==3.13.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 11)) (3.13.3)
# Requirement already satisfied: aiosignal==1.4.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 82)) (1.4.0)
# Requirement already satisfied: annotated-doc==0.0.4 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 86)) (0.0.4)
# Requirement already satisfied: anyio==4.12.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 90)) (4.12.1)
# Requirement already satisfied: attrs==25.4.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 94)) (25.4.0)
# Requirement already satisfied: certifi==2026.2.25 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 98)) (2026.2.25)
# Requirement already satisfied: charset-normalizer==3.4.5 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 105)) (3.4.5)
# Requirement already satisfied: click==8.3.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 157)) (8.3.1)
# Requirement already satisfied: contourpy==1.3.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 167)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 235)) (0.12.1)
# Requirement already satisfied: datasets==4.7.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 239)) (4.7.0)
# Requirement already satisfied: dill==0.4.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 243)) (0.4.0)
# Requirement already satisfied: filelock==3.25.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 249)) (3.25.1)
# Requirement already satisfied: fonttools==4.62.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 256)) (4.62.1)
# Requirement already satisfied: frozenlist==1.8.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 292)) (1.8.0)
# Requirement already satisfied: fsspec==2026.2.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 378)) (2026.2.0)
# Requirement already satisfied: grpcio==1.78.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 385)) (1.78.0)
# Requirement already satisfied: h11==0.16.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 418)) (0.16.0)
# Requirement already satisfied: hf-xet==1.3.2 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 422)) (1.3.2)
# Requirement already satisfied: httpcore==1.0.9 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 449)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 453)) (0.28.1)
# Requirement already satisfied: huggingface-hub==1.6.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 459)) (1.6.0)
# Requirement already satisfied: idna==3.11 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 463)) (3.11)
# Requirement already satisfied: jinja2==3.1.6 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 471)) (3.1.6)
# Requirement already satisfied: joblib==1.5.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 475)) (1.5.3)
# Requirement already satisfied: kiwisolver==1.5.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 479)) (1.5.0)
# Requirement already satisfied: markdown==3.10.2 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 560)) (3.10.2)
# Requirement already satisfied: markdown-it-py==4.0.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 564)) (4.0.0)
# Requirement already satisfied: markupsafe==3.0.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 568)) (3.0.3)
# Requirement already satisfied: matplotlib==3.10.8 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 628)) (3.10.8)
# Requirement already satisfied: mdurl==0.1.2 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 666)) (0.1.2)
# Requirement already satisfied: mpmath==1.3.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 670)) (1.3.0)
# Requirement already satisfied: multidict==6.7.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 674)) (6.7.1)
# Requirement already satisfied: multiprocess==0.70.18 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 770)) (0.70.18)
# Requirement already satisfied: networkx==3.6.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 779)) (3.6.1)
# Requirement already satisfied: numpy==2.4.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 783)) (2.4.3)
# Requirement already satisfied: packaging==26.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 902)) (26.0)
# Requirement already satisfied: pandas==3.0.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 910)) (3.0.1)
# Requirement already satisfied: pillow==12.1.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 954)) (12.1.1)
# Requirement already satisfied: propcache==0.4.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1020)) (0.4.1)
# Requirement already satisfied: protobuf==7.34.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1101)) (7.34.0)
# Requirement already satisfied: pyarrow==23.0.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1113)) (23.0.1)
# Requirement already satisfied: pygments==2.19.2 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1151)) (2.19.2)
# Requirement already satisfied: pyparsing==3.3.2 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1155)) (3.3.2)
# Requirement already satisfied: pypickle==2.0.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1159)) (2.0.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1163)) (2.9.0.post0)
# Requirement already satisfied: pyyaml==6.0.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1169)) (6.0.3)
# Requirement already satisfied: requests==2.32.5 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1212)) (2.32.5)
# Requirement already satisfied: rich==14.3.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1216)) (14.3.3)
# Requirement already satisfied: scikit-learn==1.8.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1220)) (1.8.0)
# Requirement already satisfied: scipy==1.17.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1253)) (1.17.1)
# Requirement already satisfied: setuptools==82.0.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1306)) (82.0.1)
# Requirement already satisfied: shellingham==1.5.4 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1312)) (1.5.4)
# Requirement already satisfied: six==1.17.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1316)) (1.17.0)
# Requirement already satisfied: sympy==1.14.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1322)) (1.14.0)
# Requirement already satisfied: tensorboard==2.20.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1326)) (2.20.0)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1329)) (0.7.2)
# Requirement already satisfied: tensorboard-pytorch==0.7.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1334)) (0.7.1)
# Requirement already satisfied: threadpoolctl==3.6.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1337)) (3.6.0)
# Requirement already satisfied: torch==2.10.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1341)) (2.10.0)
# Requirement already satisfied: tqdm==4.67.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1370)) (4.67.3)
# Requirement already satisfied: typer==0.24.1 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1383)) (0.24.1)
# Requirement already satisfied: typing-extensions==4.15.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1387)) (4.15.0)
# Requirement already satisfied: urllib3==2.6.3 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1400)) (2.6.3)
# Requirement already satisfied: werkzeug==3.1.6 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1404)) (3.1.6)
# Requirement already satisfied: xxhash==3.6.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1408)) (3.6.0)
# Requirement already satisfied: yarl==1.23.0 in /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/.venv1/lib/python3.13/site-packages (from -r ../requirements.txt (line 1486)) (1.23.0)

# %%
import sys
import os

sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

# %%
import pandas as pd

from pathlib import Path

from pytorch.prepare.model import load_model, evaluate_dataset

project_root = Path().resolve().parent

model, vectorizer, label_map, model_type = load_model("../src/pytorch/model.pth")
# Out:
# Loaded model type from checkpoint: dnn

# %%
dataset_path = project_root / "src" / "pytorch" / "data" / "subm1.csv"

df = pd.read_csv(dataset_path, sep=";")

# %%
evaluate_dataset(
    model,
    vectorizer,
    label_map,
    dataset_path,
    "./subm1-g8-MIA-B.csv"
)
# Out:
# Loading dataset: /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/src/pytorch/data/subm1.csv
# Dataset loaded: 150 samples
# Predictions saved to submission.csv
# np.float64(0.0)
