# %%
# !pip install -r ../requirements.txt

# %%
import sys
import os

sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

# %%
import pandas as pd

from pathlib import Path

from models.dnn.prepare.model import Model

loaded_model = Model.load("../models/numpy-dnn-model.pkl")

project_root = Path().resolve().parent

dataset_path = project_root / "src" / "data" / "subm1.csv"

# %%
df = pd.read_csv(dataset_path, sep=";")

# %%
X = df["Text"].tolist()

predicted_labels = loaded_model.predict(X)

# %%
df["Labels"] = predicted_labels

# %%
df.to_csv("./subm1-g8-MIA-A.csv", index=False, sep=";")
