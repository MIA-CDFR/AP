# %%
# !pip install -r ../requirements.txt
# Out:
# zsh:1: command not found: pip

# %%
import sys
import os

sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

# %%
import pandas as pd

from pathlib import Path

from models.transformer.transform import TransformModel

project_root = Path().resolve().parent

model_path = project_root / "models" / "transformer-fp16.pth"
model = TransformModel.load(model_path)
# Out:
# /Users/diego/Workspace/Simb/mia/2-semestre/trabalhos/AP/src/models/transformer/classifier/transformer.py:19: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=2)

# %%
dataset_path = project_root / "src" / "data" / "subm2.csv"

df = pd.read_csv(dataset_path, sep=";")

# %%
X = df["Text"].tolist()

predicted_labels = model.predict(X)

df["Labels"] = predicted_labels

# %%
df.to_csv("./subm2-g8-MIA-B.csv", index=False, sep=";")
